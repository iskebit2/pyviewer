# %%
for w in [[1,0,0],[0,1,0], [-1,0,0],[0,-1,0]]:
    print(f"\n=== Wind: {w} ===")
    # Her analiz öncesi temizle
    for surf in building.surfaces_items.values():
        for e in surf.edges.values():
            e["shared"] = []
            e["same_axis"] = []
            e["leading"] = False
        surf.global_leading = False
        surf.properties["global_leading"] = False
    building.analysis_all_roof_wind(w)
